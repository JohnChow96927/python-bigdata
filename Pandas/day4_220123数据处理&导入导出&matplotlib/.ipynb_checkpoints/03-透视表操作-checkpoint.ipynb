# %%
import pandas as pd

# %% [markdown]
# # 透视表操作示例

# %% [markdown]
# ##### 作用：对 DataFrame 进行透视表操作，本质是进行分组聚合
# **pd.pivot_table(df, index, columns, values, aggfunc='mean')**<br/>
# 或<br/>
# **df.pivot_table(index, columns, values, aggfunc='mean')**<br/>
# 参数：<br/>
# * df：DataFrame数据
# * index：指定列标签，该列的值作为结果中的行标签
# * columns：指定列标签，该列的值作为结果中的列标签
# * values：指定列标签，依据index和columns指定的列一起分组，并对values指定的列进行聚合
# * aggfunc：聚合方法，默认是mean

# %% [markdown]
# ## 示例1

# %% [markdown]
# **加载优衣库门店销售数据 uniqlo.csv**

# %%
uniqlo = pd.read_csv('./data/uniqlo.csv')
uniqlo.head()
# Out:
#    store_id city channel gender_group age_group  wkd_ind product  customer  \
# 0       658   深圳      线下       Female     25-29  Weekday    当季新品         4
# 1       146   杭州      线下       Female     25-29  Weekday      运动         1
# 2        70   深圳      线下         Male      >=60  Weekday      T恤         2
# 3       658   深圳      线下       Female     25-29  Weekday      T恤         1
# 4       229   深圳      线下         Male     20-24  Weekend      袜子         2
#
#    revenue  order  quant  unit_cost
# 0    796.0      4      4         59
# 1    149.0      1      1         49
# 2    178.0      2      2         49
# 3     59.0      1      1         49
# 4     65.0      2      3          9

# %%
uniqlo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22293 entries, 0 to 22292
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   store_id      22293 non-null  int64
#  1   city          22293 non-null  object
#  2   channel       22293 non-null  object
#  3   gender_group  22293 non-null  object
#  4   age_group     22293 non-null  object
#  5   wkd_ind       22293 non-null  object
#  6   product       22293 non-null  object
#  7   customer      22293 non-null  int64
#  8   revenue       22293 non-null  float64
#  9   order         22293 non-null  int64
#  10  quant         22293 non-null  int64
#  11  unit_cost     22293 non-null  int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 2.0+ MB

# %% [markdown]
# **示例1：统计不同种类产品在不同城市的销量**

# %%
# 分组聚合
# 分组聚合操作：统计不同种类产品在不同城市的销量
result = uniqlo.groupby(['product', 'city'])['quant'].sum()
result
# Out:
# product  city
# T恤       上海      2118
#          北京       800
#          南京       568
#          广州      1681
#          成都      1079
#                  ...
# 配件       杭州       777
#          武汉       755
#          深圳      1046
#          西安       260
#          重庆       339
# Name: quant, Length: 90, dtype: int64

# %%
# unstack 操作
result = result.unstack()
result
# Out:
# city       上海   北京   南京    广州    成都    杭州    武汉    深圳    西安    重庆
# product
# T恤       2118  800  568  1681  1079  3100  2964  3697  1145  1273
# 当季新品      550  188  266   459   329   840   862  1126   281   437
# 毛衣        131   37   44   149    92   238   202   248   105   110
# 牛仔裤       307   46   52   194   178   388   415   477   152   223
# 短裤        306   87   49   266   179   456   490   608   174   206
# 袜子        370  123  117   379   240   662   568   735   186   259
# 裙子        102   27   26   107    77   163   165   201    71    56
# 运动        171   31   17   174   125   351   282   364   118   161
# 配件        550  138  126   406   225   777   755  1046   260   339

# %%
# 透视表操作
# 透视表操作
uniqlo.pivot_table(index='product', 
                   columns='city', 
                   values='quant', 
                   aggfunc='sum')
# Out:
# city       上海   北京   南京    广州    成都    杭州    武汉    深圳    西安    重庆
# product
# T恤       2118  800  568  1681  1079  3100  2964  3697  1145  1273
# 当季新品      550  188  266   459   329   840   862  1126   281   437
# 毛衣        131   37   44   149    92   238   202   248   105   110
# 牛仔裤       307   46   52   194   178   388   415   477   152   223
# 短裤        306   87   49   266   179   456   490   608   174   206
# 袜子        370  123  117   379   240   662   568   735   186   259
# 裙子        102   27   26   107    77   163   165   201    71    56
# 运动        171   31   17   174   125   351   282   364   118   161
# 配件        550  138  126   406   225   777   755  1046   260   339

# %% [markdown]
# ## 示例2

# %%
uniqlo
# Out:
#        store_id city channel gender_group age_group  wkd_ind product  \
# 0           658   深圳      线下       Female     25-29  Weekday    当季新品
# 1           146   杭州      线下       Female     25-29  Weekday      运动
# 2            70   深圳      线下         Male      >=60  Weekday      T恤
# 3           658   深圳      线下       Female     25-29  Weekday      T恤
# 4           229   深圳      线下         Male     20-24  Weekend      袜子
# ...         ...  ...     ...          ...       ...      ...     ...
# 22288       146   杭州      线下       Female     30-34  Weekday      短裤
# 22289       430   成都      线下       Female     25-29  Weekend      T恤
# 22290       449   武汉      线下       Female     35-39  Weekday      T恤
# 22291       758   杭州      线下       Female     20-24  Weekday      袜子
# 22292       616   成都      线下         Male     30-34  Weekday    当季新品
#
#        customer  revenue  order  quant  unit_cost
# 0             4    796.0      4      4         59
# 1             1    149.0      1      1         49
# 2             2    178.0      2      2         49
# 3             1     59.0      1      1         49
# 4             2     65.0      2      3          9
# ...         ...      ...    ...    ...        ...
# 22288         1     80.0      1      2         19
# 22289         1     79.0      1      1         49
# 22290         1    158.0      1      2         49
# 22291         1     26.0      1      1          9
# 22292         1     79.0      1      1         59
#
# [22293 rows x 12 columns]

# %% [markdown]
# **示例2：统计不同城市、不同渠道，不同种类产品的销售额**

# %%
# 分组聚合
result = uniqlo.groupby(['city', 'channel', 'product'])['revenue'].sum()
result
# Out:
# city  channel  product
# 上海    线上       T恤         48637.48
#                当季新品       16136.50
#                毛衣          5019.00
#                牛仔裤         9264.93
#                短裤          4453.04
#                             ...
# 重庆    线下       短裤          6149.23
#                袜子          8024.23
#                裙子          7897.00
#                运动          9284.50
#                配件         30133.90
# Name: revenue, Length: 135, dtype: float64

# %%
result = result.unstack()
result
# Out:
# product              T恤       当季新品        毛衣       牛仔裤        短裤        袜子  \
# city channel
# 上海   线上        48637.48   16136.50   5019.00   9264.93   4453.04   4379.45
#      线下       126778.56   39138.31  18766.67  22752.47   7206.38   9336.49
# 北京   线下        70349.96   18854.86   7210.68   4309.00   3241.67   4658.24
# 南京   线下        47702.91   36697.68   7525.10   5753.63   1836.22   4258.62
# 广州   线上        93729.71   26574.95  14410.00   9957.90   6433.92   8791.61
#      线下        47157.01   18994.00  10461.00   6169.00   3481.07   4724.00
# 成都   线下        89127.68   35935.63  15638.33  14922.04   7103.22   8095.41
# 杭州   线下       253602.43   99377.30  45169.62  36259.89  17715.38  21559.65
# 武汉   线上       120358.13   32243.46  22981.63  19537.13   9894.47  10715.32
#      线下       132910.00   64175.42  15849.00  27968.16   8709.19   9866.31
# 深圳   线下       309042.79  127637.43  44161.03  50120.39  23214.33  25822.56
# 西安   线上        11311.93    4158.34   1095.00   3043.00   1127.00   1458.00
#      线下        83574.01   24108.42  17331.74  12822.32   5341.88   4967.47
# 重庆   线上         7894.00    5138.00   3228.00   2421.00   1578.88   1074.00
#      线下        96568.24   41494.58  16784.00  20826.62   6149.23   8024.23
#
# product             裙子        运动         配件
# city channel
# 上海   线上        5341.00   2264.00   18942.69
#      线下        9632.93   9119.17   32652.66
# 北京   线下        3829.55   2214.00   15790.66
# 南京   线下        4168.00   1406.34   13802.43
# 广州   线上        5932.00   6438.67   28624.54
#      线下        8013.56   3929.32   14302.23
# 成都   线下       10160.33   7678.66   19528.56
# 杭州   线下       21385.04  23875.08   70574.10
# 武汉   线上       10086.00   6106.36   49498.23
#      线下       13669.26  11760.96   23448.75
# 深圳   线下       27572.11  24339.68  101213.36
# 西安   线上        2331.00   1386.20    4177.54
#      线下        7086.00   5629.27   19825.50
# 重庆   线上         199.00   2627.47    2170.00
#      线下        7897.00   9284.50   30133.90

# %%
# 透视表操作
uniqlo.pivot_table(index=['city','channel'], columns='product', values='revenue', aggfunc='sum')
# Out:
# product              T恤       当季新品        毛衣       牛仔裤        短裤        袜子  \
# city channel
# 上海   线上        48637.48   16136.50   5019.00   9264.93   4453.04   4379.45
#      线下       126778.56   39138.31  18766.67  22752.47   7206.38   9336.49
# 北京   线下        70349.96   18854.86   7210.68   4309.00   3241.67   4658.24
# 南京   线下        47702.91   36697.68   7525.10   5753.63   1836.22   4258.62
# 广州   线上        93729.71   26574.95  14410.00   9957.90   6433.92   8791.61
#      线下        47157.01   18994.00  10461.00   6169.00   3481.07   4724.00
# 成都   线下        89127.68   35935.63  15638.33  14922.04   7103.22   8095.41
# 杭州   线下       253602.43   99377.30  45169.62  36259.89  17715.38  21559.65
# 武汉   线上       120358.13   32243.46  22981.63  19537.13   9894.47  10715.32
#      线下       132910.00   64175.42  15849.00  27968.16   8709.19   9866.31
# 深圳   线下       309042.79  127637.43  44161.03  50120.39  23214.33  25822.56
# 西安   线上        11311.93    4158.34   1095.00   3043.00   1127.00   1458.00
#      线下        83574.01   24108.42  17331.74  12822.32   5341.88   4967.47
# 重庆   线上         7894.00    5138.00   3228.00   2421.00   1578.88   1074.00
#      线下        96568.24   41494.58  16784.00  20826.62   6149.23   8024.23
#
# product             裙子        运动         配件
# city channel
# 上海   线上        5341.00   2264.00   18942.69
#      线下        9632.93   9119.17   32652.66
# 北京   线下        3829.55   2214.00   15790.66
# 南京   线下        4168.00   1406.34   13802.43
# 广州   线上        5932.00   6438.67   28624.54
#      线下        8013.56   3929.32   14302.23
# 成都   线下       10160.33   7678.66   19528.56
# 杭州   线下       21385.04  23875.08   70574.10
# 武汉   线上       10086.00   6106.36   49498.23
#      线下       13669.26  11760.96   23448.75
# 深圳   线下       27572.11  24339.68  101213.36
# 西安   线上        2331.00   1386.20    4177.54
#      线下        7086.00   5629.27   19825.50
# 重庆   线上         199.00   2627.47    2170.00
#      线下        7897.00   9284.50   30133.90

# %% [markdown]
# ## 示例3

# %%
uniqlo
# Out:
#        store_id city channel gender_group age_group  wkd_ind product  \
# 0           658   深圳      线下       Female     25-29  Weekday    当季新品
# 1           146   杭州      线下       Female     25-29  Weekday      运动
# 2            70   深圳      线下         Male      >=60  Weekday      T恤
# 3           658   深圳      线下       Female     25-29  Weekday      T恤
# 4           229   深圳      线下         Male     20-24  Weekend      袜子
# ...         ...  ...     ...          ...       ...      ...     ...
# 22288       146   杭州      线下       Female     30-34  Weekday      短裤
# 22289       430   成都      线下       Female     25-29  Weekend      T恤
# 22290       449   武汉      线下       Female     35-39  Weekday      T恤
# 22291       758   杭州      线下       Female     20-24  Weekday      袜子
# 22292       616   成都      线下         Male     30-34  Weekday    当季新品
#
#        customer  revenue  order  quant  unit_cost
# 0             4    796.0      4      4         59
# 1             1    149.0      1      1         49
# 2             2    178.0      2      2         49
# 3             1     59.0      1      1         49
# 4             2     65.0      2      3          9
# ...         ...      ...    ...    ...        ...
# 22288         1     80.0      1      2         19
# 22289         1     79.0      1      1         49
# 22290         1    158.0      1      2         49
# 22291         1     26.0      1      1          9
# 22292         1     79.0      1      1         59
#
# [22293 rows x 12 columns]

# %% [markdown]
# **示例3：统计不同种类产品的销售额**

# %%
# 分组聚合
uniqlo.groupby('product')[['revenue']].sum()
# Out:
#             revenue
# product
# T恤       1538744.84
# 当季新品      590664.88
# 毛衣        245630.80
# 牛仔裤       246127.48
# 短裤        107485.88
# 袜子        127731.36
# 裙子        137302.78
# 运动        118059.68
# 配件        444685.15

# %%
uniqlo.pivot_table(index='product', values='revenue', aggfunc='sum')
# Out:
#             revenue
# product
# T恤       1538744.84
# 当季新品      590664.88
# 毛衣        245630.80
# 牛仔裤       246127.48
# 短裤        107485.88
# 袜子        127731.36
# 裙子        137302.78
# 运动        118059.68
# 配件        444685.15

# %%
# 透视表操作

# %% [markdown]
# ## 示例4

# %%
uniqlo
# Out:
#        store_id city channel gender_group age_group  wkd_ind product  \
# 0           658   深圳      线下       Female     25-29  Weekday    当季新品
# 1           146   杭州      线下       Female     25-29  Weekday      运动
# 2            70   深圳      线下         Male      >=60  Weekday      T恤
# 3           658   深圳      线下       Female     25-29  Weekday      T恤
# 4           229   深圳      线下         Male     20-24  Weekend      袜子
# ...         ...  ...     ...          ...       ...      ...     ...
# 22288       146   杭州      线下       Female     30-34  Weekday      短裤
# 22289       430   成都      线下       Female     25-29  Weekend      T恤
# 22290       449   武汉      线下       Female     35-39  Weekday      T恤
# 22291       758   杭州      线下       Female     20-24  Weekday      袜子
# 22292       616   成都      线下         Male     30-34  Weekday    当季新品
#
#        customer  revenue  order  quant  unit_cost
# 0             4    796.0      4      4         59
# 1             1    149.0      1      1         49
# 2             2    178.0      2      2         49
# 3             1     59.0      1      1         49
# 4             2     65.0      2      3          9
# ...         ...      ...    ...    ...        ...
# 22288         1     80.0      1      2         19
# 22289         1     79.0      1      1         49
# 22290         1    158.0      1      2         49
# 22291         1     26.0      1      1          9
# 22292         1     79.0      1      1         59
#
# [22293 rows x 12 columns]

# %% [markdown]
# **示例4：统计不同城市销售的产品种类数和产品的总销售额**

# %%
# 分组聚合
# 分组聚合操作
uniqlo.groupby('city').agg({'product': 'nunique', 'revenue': 'sum'})
# Out:
#       product    revenue
# city
# 上海          9  389821.73
# 北京          9  130458.62
# 南京          9  123150.93
# 广州          9  318124.49
# 成都          9  208189.86
# 杭州          9  589518.49
# 武汉          9  589777.78
# 深圳          9  733123.68
# 西安          9  210774.62
# 重庆          9  263492.65

# %%
# 透视表操作
uniqlo.pivot_table(index='city', values=['product', 'revenue'], 
                   aggfunc={'product': 'nunique', 'revenue': 'sum'})
# Out:
#       product    revenue
# city
# 上海          9  389821.73
# 北京          9  130458.62
# 南京          9  123150.93
# 广州          9  318124.49
# 成都          9  208189.86
# 杭州          9  589518.49
# 武汉          9  589777.78
# 深圳          9  733123.68
# 西安          9  210774.62
# 重庆          9  263492.65
