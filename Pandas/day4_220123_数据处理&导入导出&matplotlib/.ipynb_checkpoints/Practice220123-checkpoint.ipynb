# %% [markdown]
# # 1. 数据整理

# %%
# 练习1：melt/pivot 函数使用
# 需求1：使用 melt 方法将 work1.csv 的数据转换为如下长数据
import pandas as pd
df = pd.read_csv('./data/work1.csv')
df_long = df.melt(id_vars=['day'], var_name='city', value_name='count')
df_long
# Out:
#           day     city  count
# 0      Monday  lucknow     65
# 1     Tuesday  lucknow     45
# 2   Wednesday  lucknow     21
# 3    Thursday  lucknow     45
# 4      Friday  lucknow     36
# 5    Saturday  lucknow     44
# 6      Sunday  lucknow     35
# 7      Monday    delhi     65
# 8     Tuesday    delhi     66
# 9   Wednesday    delhi     68
# 10   Thursday    delhi     75
# 11     Friday    delhi     78
# 12   Saturday    delhi     82
# 13     Sunday    delhi     48
# 14     Monday  kolkata     56
# 15    Tuesday  kolkata     58
# 16  Wednesday  kolkata     60
# 17   Thursday  kolkata     80
# 18     Friday  kolkata     83
# 19   Saturday  kolkata     85
# 20     Sunday  kolkata     26

# %%
# 需求2：使用 pivot 方法将需求1的结果再转换为如下宽数据
df_wide = df_long.pivot(index='day',columns='city', values='count')
df_wide.reset_index()
df_wide
# Out:
# city       delhi  kolkata  lucknow
# day
# Friday        78       83       36
# Monday        65       56       65
# Saturday      82       85       44
# Sunday        48       26       35
# Thursday      75       80       45
# Tuesday       66       58       45
# Wednesday     68       60       21

# %%
# 练习2：stack/unstack 函数的使用
# 需求1：使用 stack 实现练习1中需求1的效果如下：
day_series = df.set_index('day').stack()
df_long = day_series.reset_index()
df_long.columns = ['day', 'city', 'count']
df_long
# Out:
#           day     city  count
# 0      Monday  lucknow     65
# 1      Monday    delhi     65
# 2      Monday  kolkata     56
# 3     Tuesday  lucknow     45
# 4     Tuesday    delhi     66
# 5     Tuesday  kolkata     58
# 6   Wednesday  lucknow     21
# 7   Wednesday    delhi     68
# 8   Wednesday  kolkata     60
# 9    Thursday  lucknow     45
# 10   Thursday    delhi     75
# 11   Thursday  kolkata     80
# 12     Friday  lucknow     36
# 13     Friday    delhi     78
# 14     Friday  kolkata     83
# 15   Saturday  lucknow     44
# 16   Saturday    delhi     82
# 17   Saturday  kolkata     85
# 18     Sunday  lucknow     35
# 19     Sunday    delhi     48
# 20     Sunday  kolkata     26

# %%
# 练习3：wide_to_long 函数的使用
# 需求：使用 wide_to_long 将 work2.csv 数据转换为如下长数据
df = pd.read_csv('./data/work2.csv')
new_df = pd.wide_to_long(df, stubnames=['ht'], i=['famid', 'birth'], j='age', sep='_')
new_df.reset_index()
new_df
# Out:
#                   ht
# famid birth age
# 1     1     1    2.8
#             2    3.4
#       2     1    2.9
#             2    3.8
#       3     1    2.2
#             2    2.9
# 2     1     1    2.0
#             2    3.2
#       2     1    1.8
#             2    2.8
#       3     1    1.9
#             2    2.4
# 3     1     1    2.2
#             2    3.3
#       2     1    2.3
#             2    3.4
#       3     1    2.1
#             2    2.9

# %% [markdown]
# # 2. 数据透视表

# %%
# 练习1：统计不同种类产品在不同城市的销量(分别使用分组聚合和透视表实现)
uniqlo = pd.read_csv('./data/uniqlo.csv')

result = uniqlo.groupby(['channel','product']).quant.sum()
result.unstack()
# Out:
# product     T恤  当季新品    毛衣   牛仔裤    短裤    袜子   裙子    运动    配件
# channel
# 线上        3254   866   248   415   626   736  158   295  1054
# 线下       15171  4472  1108  2017  2195  2903  837  1499  3568

# %%
# 练习2：统计不同销售渠道中男性和女性客户的总销售额(分别使用分组聚合和透视表实现）
result = uniqlo.groupby(['channel', 'gender_group']).revenue.sum()
result.unstack()
# Out:
# gender_group      Female       Male   Unkown
# channel
# 线上             449266.64  201011.84  2892.00
# 线下            2078492.70  817558.81  7210.86

# %%
uniqlo.pivot_table(index='channel', columns='gender_group', values='revenue', aggfunc='sum')
# Out:
# gender_group      Female       Male   Unkown
# channel
# 线上             449266.64  201011.84  2892.00
# 线下            2078492.70  817558.81  7210.86

# %%
# 练习3：统计不同销售渠道销售的订单数和总销售额
uniqlo.groupby('channel')[['order', 'revenue']].sum()
# Out:
#          order     revenue
# channel
# 线上        6823   653170.48
# 线下       30005  2903262.37

# %%
uniqlo.pivot_table(index='channel', values=['order', 'revenue'], aggfunc={'order': 'sum', 'revenue': 'sum'})
# Out:
#          order     revenue
# channel
# 线上        6823   653170.48
# 线下       30005  2903262.37

# %% [markdown]
# # 3. 数据的导入和导出

# %%
# 练习1：pandas 从 winfunc 数据库中导入 movie 表和 review 表的数据
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:123456@127.0.0.1:3306/sql_exam?charset=utf8')

movie = pd.read_sql('movie', engine)
review = pd.read_sql('review', engine)

# %%
# 练习2：pandas 加载之后，将左侧和右侧数据按照电影 ID 进行关联
result = pd.merge(movie, review, left_on='id', right_on='movie_id')
result
# Out:
#     id_x   title release_year genre  editor_rating  id_y  rating  customer_id  \
# 0      1     阿凡达         2009    科幻              8     1       7            2
# 1      1     阿凡达         2009    科幻              8     2       8            6
# 2      2   泰坦尼克号         1997    剧情             10     3      10            1
# 3      2   泰坦尼克号         1997    剧情             10     4      10            2
# 4      2   泰坦尼克号         1997    剧情             10     5       8            3
# 5      2   泰坦尼克号         1997    剧情             10     6       9            1
# 6      3      教父         1972    剧情              8     7       9            3
# 7      3      教父         1972    剧情              8     8       9            7
# 8      3      教父         1972    剧情              8     9       8            2
# 9      3      教父         1972    剧情              8    10       6            5
# 10     4    艳舞女郎         1995   纪录片              3    11       3            5
# 11     4    艳舞女郎         1995   纪录片              3    12       3            3
# 12     4    艳舞女郎         1995   纪录片              3    13       5            6
# 13     4    艳舞女郎         1995   纪录片              3    14       1            2
# 14     5  外太空计划9         1959    科幻              2    15       1            1
# 15     5  外太空计划9         1959    科幻              2    16       1            3
# 16     5  外太空计划9         1959    科幻              2    17       3            4
# 17     5  外太空计划9         1959    科幻              2    18       2            7
#
#     movie_id
# 0          1
# 1          1
# 2          2
# 3          2
# 4          2
# 5          2
# 6          3
# 7          3
# 8          3
# 9          3
# 10         4
# 11         4
# 12         4
# 13         4
# 14         5
# 15         5
# 16         5
# 17         5

# %%
# 练习3：统计不同电影的用户平均分，并将统计结果导出到 movie_rating 数据表中

# %%
movie_avg_rating = result.groupby(['movie_id', 'title']).rating.mean()
movie_avg_rating.reset_index()
movie_avg_rating.to_sql('movie_rating', engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
# -> 1802                     self.dialect.do_execute(
#    1803                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (1170, "BLOB/TEXT column 'title' used in key specification without a key length")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /var/folders/qj/p7t463bd1kqbxrjtymhqhzl00000gn/T/ipykernel_11374/3254024807.py in <module>
#       1 movie_avg_rating = result.groupby(['movie_id', 'title']).rating.mean()
#       2 movie_avg_rating.reset_index()
# ----> 3 movie_avg_rating.to_sql('movie_rating', engine)
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2600         from pandas.io import sql
#    2601
# -> 2602         sql.to_sql(
#    2603             self,
#    2604             name,
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1391             dtype=dtype,
#    1392         )
# -> 1393         table.create()
#    1394
#    1395         from sqlalchemy import exc
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/sql.py in create(self)
#     730                 raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     731         else:
# --> 732             self._execute_create()
#     733
#     734     def _execute_insert(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/sql.py in _execute_create(self)
#     716         # Inserting table into database, add to MetaData object
#     717         self.table = self.table.tometadata(self.pd_sql.meta)
# --> 718         self.table.create()
#     719
#     720     def create(self):
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/sql/schema.py in create(self, bind, checkfirst)
#     948         if bind is None:
#     949             bind = _bind_or_error(self)
# --> 950         bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#     951
#     952     def drop(self, bind=None, checkfirst=False):
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3115     def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    3116         with self.begin() as conn:
# -> 3117             conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#    3118
#    3119     @util.deprecated_20(
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2111
#    2112         """
# -> 2113         visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#    2114
#    2115     @util.deprecated(
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/sql/visitors.py in traverse_single(self, obj, **kw)
#     522             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     523             if meth:
# --> 524                 return meth(obj, **kw)
#     525
#     526     def iterate(self, obj):
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/sql/ddl.py in visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     903         if hasattr(table, "indexes"):
#     904             for index in table.indexes:
# --> 905                 self.traverse_single(index, create_ok=True)
#     906
#     907         if self.dialect.supports_comments and not self.dialect.inline_comments:
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/sql/visitors.py in traverse_single(self, obj, **kw)
#     522             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     523             if meth:
# --> 524                 return meth(obj, **kw)
#     525
#     526     def iterate(self, obj):
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/sql/ddl.py in visit_index(self, index, create_ok)
#     934         if not create_ok and not self._can_create_index(index):
#     935             return
# --> 936         self.connection.execute(CreateIndex(index))
#     937
#     938
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1287             )
#    1288         else:
# -> 1289             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1290
#    1291     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/sql/ddl.py in _execute_on_connection(self, connection, multiparams, params, execution_options)
#      78         self, connection, multiparams, params, execution_options
#      79     ):
# ---> 80         return connection._execute_ddl(
#      81             self, multiparams, params, execution_options
#      82         )
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_ddl(self, ddl, multiparams, params, execution_options)
#    1379             dialect=dialect, schema_translate_map=schema_translate_map
#    1380         )
# -> 1381         ret = self._execute_context(
#    1382             dialect,
#    1383             dialect.execution_ctx_cls._init_ddl,
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843
#    1844         except BaseException as e:
# -> 1845             self._handle_dbapi_exception(
#    1846                 e, statement, parameters, cursor, context
#    1847             )
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025             elif should_wrap:
# -> 2026                 util.raise_(
#    2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1800                             break
#    1801                 if not evt_handled:
# -> 1802                     self.dialect.do_execute(
#    1803                         cursor, statement, parameters, context
#    1804                     )
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~/opt/anaconda3/envs/datasci/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1170, "BLOB/TEXT column 'title' used in key specification without a key length")
# [SQL: CREATE INDEX ix_movie_rating_title ON movie_rating (title)]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
